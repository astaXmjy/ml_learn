# %% [markdown]
# House Price Prediction Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.head(5)
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10, 6))
sns.displot(df['price'],kind='kde', fill=True, color='blue')

# %%
sns.countplot(x='bedrooms', data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
df.drop(['id', 'date'], axis=1, inplace=True)

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308787   0.525906     0.701917  0.089876  0.256804
# bedrooms       0.308787  1.000000   0.514508     0.578212  0.032471  0.177944
# bathrooms      0.525906  0.514508   1.000000     0.755758  0.088373  0.502582
# sqft_living    0.701917  0.578212   0.755758     1.000000  0.173453  0.353953
# sqft_lot       0.089876  0.032471   0.088373     0.173453  1.000000 -0.004814
# floors         0.256804  0.177944   0.502582     0.353953 -0.004814  1.000000
# waterfront     0.266398 -0.006834   0.063744     0.103854  0.021632  0.023755
# view           0.397370  0.080008   0.188386     0.284709  0.074900  0.028814
# condition      0.036056  0.026496  -0.126479    -0.059445 -0.008830 -0.264075
# grade          0.667951  0.356563   0.665838     0.762779  0.114731  0.458794
# sqft_above     0.605368  0.479386   0.686668     0.876448  0.184139  0.523989
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price', y='sqft_living', data=df, color='blue')
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='bedrooms', y='price', data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price',y='long', data=df, color='blue')
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price',y='lat', data=df, color='blue')
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='long', y='lat', data=df, color='blue',hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price', ascending=False).head(10)
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7245  7700000.0         6       8.00        12050     27600     2.5
# 3910  7060000.0         5       4.50        10040     37325     2.0
# 9245  6890000.0         6       7.75         9890     31374     2.0
# 4407  5570000.0         5       5.75         9200     35069     2.0
# 1446  5350000.0         5       5.00         8000     23985     2.0
# 1313  5300000.0         6       6.00         7390     24829     2.0
# 1162  5110000.0         5       5.25         8010     45517     2.0
# 8085  4670000.0         5       6.75         9640     13068     1.0
# 2624  4500000.0         5       5.50         6640     40014     2.0
# 8629  4490000.0         4       3.00         6430     27517     2.0
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 7245           0     3          4     13        8570           3480      1910
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
non_top_1_percent = df.sort_values('price', ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='long', y='lat', data=non_top_1_percent, color='blue',hue='price',edgecolor=None, alpha=0.5,palette='RdYlGn')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront', y='price', data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>
